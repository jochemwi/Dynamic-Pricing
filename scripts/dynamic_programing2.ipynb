# %% [markdown]
# # Import packages needed for running code

# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt
from scipy.stats import poisson
import pandas as pd
import random as rd
import itertools as it

# %% [markdown]
# # Define model's parameters

# %%
M = 5  # max. shelf life
mu = 3  # mean demand of Poisson distribution
Dmx = 3 * mu  # trunacte demand ceiling; you cannot realistically sell more
prob = pmf_values = poisson.pmf(np.arange(0, Dmx + 1), mu)
prob[Dmx] = 1 - prob[0:Dmx].sum()

z = 1 / sqrt(2)  # for 1 day of safety stock set z = 1/sqrt(2)

# Dmx is the practical upperbound and 2 * mu + z * sqrt(2) * mu
# is a statistical motivated amount. Choose the lowest as the maximum
# number of items on the shelf per item age.
UBI = min(Dmx, 2 * mu + z * sqrt(2) * mu)  # Upperbound on \# items in each age class

r = 250  # regular sales price (excl. discount)
c = 175  # purchase price

Tw = 10  # warmin up period of simulation (is excluded in calculating statistics)
T = Tw + 36500  # length of a simulation (episode length).

# %% [markdown]
# # Reserve memory for variables

# %%
def initialize():
    # (this prevents high RAM use until Garbage collection)
    I = np.empty([T + 1, M], dtype=int)
    IL = np.empty([T, M], dtype=int)
    BSPlvl = np.empty(T, dtype=int)
    Order = np.empty(T, dtype=int)
    D = np.empty(T, dtype=int)
    DF = np.empty(T, dtype=int)
    DL = np.empty(T, dtype=int)
    DeltaF = np.empty([T, M], dtype=int)
    DeltaL = np.empty([T, M], dtype=int)
    SALES = np.empty(T, dtype=int)
    PRF = np.empty(T)
    LS = np.empty(T, dtype=int)
    WST = np.empty(T, dtype=int)
    Profit = np.zeros(11)
    return I, IL, BSPlvl, Order, D, DF, DL, DeltaF, DeltaL, SALES, PRF, LS, WST, Profit

# %% [markdown]
# # Optional functions to make states into string

# %%
def State2Index(I):
    idx = I[0]
    for i in range(1, M):
        idx = (1 + UBI) * idx + I[i]
    return idx


def Index2State(idx):
    Ilist = []
    for i in range(M):
        idx1 = int(idx / (1 + UBI))
        Ilist.append(idx - idx1 * (1 + UBI))
        print(idx, idx1, Ilist)
        idx = idx1
    return np.array(Ilist.reverse())

# %% [markdown]
# # Define state space, probabilities, action space and reward space

# %%
BSPlvl = round(2 * mu + z * sqrt(2) * mu)
S = np.arange(BSPlvl + 1)
SS = np.array(list(it.product(S, repeat = M)))

valid = SS.sum(axis=1) <= BSPlvl
SS = SS[valid]
nS = len(SS)
s1 = np.zeros(M)

AA = np.arange(11)
nA = len(AA)

RR = np.zeros([nA, nS])
PP = np.zeros([nA, nS, nS]) # Changed nS1 to nS for the third dimension

# %% [markdown]
# # Run the model for each action.
# <ol>
#   <li>Action: a discount on the oldest product.</li>
#   <li>Reward: LEFO + FEFO - order costs</li>
#   <li>State: combination of number of items per product age per day</li>
#   <li>Probability: poisson model distribution around mu = 3</li>
# </ol>

# %% [markdown]
# # Check how many states per action are possible

# %%
def check_states(PP, nA):
    print(f"Total number of states (second dimension): {PP.shape[1]}")
    for i in range(nA):
        count = 0
        for j in range(PP.shape[1]):  # use PP.shape[1] instead of nS to adapt dynamically
            if PP[i, j, :].sum() == 1.0:
                count += 1
        print(f'Action {i} has {count} possible states.')

# %%
for ida, a in enumerate(AA): # action: discount
    rd.seed(1)
    np.random.seed(1)
    IL = np.zeros(M, dtype=int)
    Order = np.zeros(1, dtype=int)
    DF = np.zeros(1, dtype=int)
    DL = np.zeros(1, dtype=int)
    DeltaF = np.zeros(M, dtype=int)
    DeltaL = np.zeros(M, dtype=int)
    SALES = np.zeros(1, dtype=int)
    PRF = np.zeros(1,dtype = float)
    LS = np.zeros(1, dtype=int)
    WST = np.zeros(1, dtype=int)

    for ids, s in enumerate(SS): # state: inventory
        # discount
        aa = 0.05 * a

        # set order quantity:
        Order = max(0, BSPlvl - s.sum())
        PRF = np.zeros(1,dtype = float)

        for idd, d in enumerate(range(Dmx + 1)): # demand
            # split demand
            DF_frac = min(s[M - 1], aa * d)
            DF_int = int(DF_frac)
            Frac = DF_frac - DF_int

            branches = [(DF_int, 1.0)] if Frac == 0 else [(DF_int, 1 - Frac), (DF_int + 1, Frac)]

            for DF, w in branches:
                DL = d - DF
                DeltaF[M - 1] = DF
                IL = s - DeltaF
                DeltaL[0] = min(DL, IL[0])
                for i in range(1, M):
                    DeltaL[i] = min(DL - DeltaL[0:i].sum(), IL[i])

                s1[:] = IL - DeltaL
                s1[:] = np.roll(s1, 1)
                s1[0] = Order

                ids1 = np.where((SS == s1).all(axis=1))[0][0].item()
                p = prob[idd]
                PP[ida, ids, ids1] += p * w
                PRF += p * w * (r * DeltaL.sum() + r * (1 - aa) * DeltaF.sum() - c * Order)
                PRF += p * w * (r * DeltaL.sum() + r * (1 - aa) * DeltaF.sum() - c * Order)
                WST = s1[M - 1]

                LS = max(0, d - s.sum())
                SALES = DeltaF + DeltaL

        RR[ida, ids] += PRF[0].item()

# %%
# before removal
print("Before removal: \n")
check_states(PP, nA)
# Out:
# Before removal:
#
# Total number of states (second dimension): 2002
# Action 0 has 1670 possible states.
# Action 1 has 1526 possible states.
# Action 2 has 1610 possible states.
# Action 3 has 1830 possible states.
# Action 4 has 1814 possible states.
# Action 5 has 1583 possible states.
# Action 6 has 1826 possible states.
# Action 7 has 1713 possible states.
# Action 8 has 1903 possible states.
# Action 9 has 1867 possible states.
# Action 10 has 1901 possible states.

# %% [markdown]
# Remove nonexisting states

# %%
mask = PP.sum(axis=2).sum(axis=0) == 0  # shape: (1287,) — True where sum is 0

# Delete all matching indices at once
SS_copy = SS[~mask]  # remove the same zero-entries from SS
PP_copy = np.delete(PP.copy(), np.where(mask)[0], axis=1)

# %%
print(f"Removed {mask.sum()} zero states\n")
print(f"SS size: {len(SS_copy)}, PP axis 1 size: {PP_copy.shape[1]}")  # should be equal
# Out:
# Removed 0 zero states
#
# SS size: 2002, PP axis 1 size: 2002

# %% [markdown]
# And check the possible states again - they should not have changed

# %%
# after removal
print("After removal: \n")
check_states(PP_copy, nA)
# Out:
# After removal:
#
# Total number of states (second dimension): 2002
# Action 0 has 1670 possible states.
# Action 1 has 1526 possible states.
# Action 2 has 1610 possible states.
# Action 3 has 1830 possible states.
# Action 4 has 1814 possible states.
# Action 5 has 1583 possible states.
# Action 6 has 1826 possible states.
# Action 7 has 1713 possible states.
# Action 8 has 1903 possible states.
# Action 9 has 1867 possible states.
# Action 10 has 1901 possible states.

# %% [markdown]
# # Use Iterative Policy Evaluation with Policy Improvement.

# %%
pi = np.random.choice(AA, size = nS)
V = np.zeros(len(SS))
V_prev = np.zeros(len(SS))
q = np.zeros([nA, len(SS)])
gamma = 0.999
PolicyNotStable = True
niterPI = 0

while PolicyNotStable:
    niterPI += 1

    # Iterative Policy evaluation
    niterIPE = 0
    theta = 0.0001 * (1 - gamma) / (2 * gamma)
    span = 1 + theta
    while span > theta:
        niterIPE += 1
        for ids, s in enumerate(SS):
            a = pi[ids]
            ida = np.where(AA == a)[0][0]  # look up the action index associated with action a
            V[ids] = RR[ida, ids] + gamma * PP[ida, ids, :] @ V_prev

        Diff = V - V_prev
        span = max(Diff) - min(Diff)
        V_prev = V.copy()  # create a copy of the content of V, rather than copy the reference to V
        niterIPE += 1

    print(niterPI, niterIPE, pi)

    # POLICY IMPROVEMENT
    pi_prev = pi.copy()
    PolicyNotStable = False
    for ids, s in enumerate(SS):
        qbest = - np.inf
        for ida, a in enumerate(AA):
            q[ida, ids] = RR[ida, ids] + gamma * PP[ida, ids, :] @ V_prev
            if q[ida, ids] > qbest:
                pi[ids] = a
                qbest = q[ida, ids]
        if pi[ids] != pi_prev[ids]:
            PolicyNotStable = True
# Out:
# 1 198 [5 8 9 ... 0 5 1]
# 2 170 [0 0 0 ... 0 0 0]
# 3 128 [0 0 0 ... 0 0 0]
# 4 52 [0 0 0 ... 0 0 0]

# %% [markdown]
# # Look into the contents of the final policy

# %%
val_d = {}
for i in pi:
    if i in val_d:
        val_d[i] += 1
    else:
        val_d[i] = 1

# %%
for key in val_d:
    print(f'{key} : {val_d[key]}')
# Out:
# 0 : 758
# 1 : 69
# 2 : 141
# 3 : 211
# 4 : 358
# 5 : 264
# 7 : 73
# 6 : 116
# 8 : 12

# %% [markdown]
# # Reference
# ## Code

# %%
I, IL, BSPlvl, Order, D, DF, DL, DeltaF, DeltaL, SALES, PRF, LS, WST, Profit = initialize()
for aa in range(11):   #LOOP OVER DISCOUNT PERCENTAGES
  # RE-INITIALIZE variables and rand seeds
    rd.seed(1)
    np.random.seed(1)
    I[:] = np.zeros([T+1, M], dtype=int)
    IL[:] = np.zeros([T, M], dtype=int)
    BSPlvl[:]  = np.zeros(T, dtype=int)
    Order[:]  = np.zeros(T, dtype=int)
    D[:]  = np.zeros(T, dtype=int)
    DF[:]  = np.zeros(T, dtype=int)
    DL[:]  = np.zeros(T, dtype=int)
    DeltaF[:] = np.zeros([T, M], dtype=int)
    DeltaL[:] = np.zeros([T, M], dtype=int)
    SALES[:]  = np.zeros(T, dtype=int)
    PRF[:]  = np.zeros(T)
    LS[:]  = np.zeros(T, dtype=int)
    WST[:]  = np.zeros(T, dtype=int)

  # SIMULATE INVENTORY DYANMICS OVER ALL PERIODS
    for t in range(T):
        # observe state
        if t<0:
            print(I[t], State2Index(I[t]))
        # predict demand and set BSP level
        BSPlvl[t] = round(2*mu + z * sqrt(2)*mu)
        # set discount
        a = 0.05 *aa
        # set order quantity:
        Order[t] = max(0, BSPlvl[t] - I[t].sum())
        # set demand:
        D[t] = min( Dmx, np.random.poisson(mu) )
        # split demand
        DF_frac = min(I[t,M-1], a * D[t] )
        DF_int = int(DF_frac)
        DF[t] = DF_int
        if DF_frac != DF_int: # stochastic rounding
            Frac = DF_frac - DF_int
            u = rd.random()
            if u < Frac:
                DF[t] = DF_int + 1
        DL[t] = D[t] - DF[t]

        # pick FEFO demand:
        DeltaF[t,M-1] = DF[t]  # only oldest are discounted (<= max I[t,M-1])
        # available for LEFO customers/adjust stock levels:
        IL[t] = I[t] - DeltaF[t]
        # pick LEFO demand:
        DeltaL[t,0] = min(DL[t], IL[t,0])   # youngest first
        for i in range(1,M):
            DeltaL[t,i] = min(DL[t] - DeltaL[t,0:i].sum() , IL[t,i])

        # adjust stock levels:
        I[t+1,:] = IL[t] - DeltaL[t]
        WST[t] = I[t+1, M-1]
        I[t+1,:] = np.roll(I[t+1],1)
        I[t+1,0] = Order[t]   # as lead time is one period
        # more stats:
        LS[t] = max( 0, D[t] - I[t].sum() )
        SALES[t] = DeltaF[t].sum() + DeltaF[t].sum()
        PRF[t] = r * DeltaL[t].sum() + r * (1-a) * DeltaF[t].sum() - c * Order[t]

  # COMPUTE & PRINT AVERAGES OF KEY PERFORMANCE MEASURES
    WasteRel = WST[Tw:T].mean() / Order[Tw:T].mean()
    Fillrate = 1 - LS[Tw:T].mean() / D[Tw:T].mean()
    Profit[aa] = PRF[Tw:T].mean()
    print(f"Discount = {a * 100:.0f}%, Profit = {Profit[aa]:.3f}, Waste = {WasteRel*100:.1f} %, Fillrate = {Fillrate*100:.1f} %")
# Out:
# Discount = 0%, Profit = 155.421, Waste = 10.3 %, Fillrate = 94.7 %
# Discount = 5%, Profit = 157.744, Waste = 9.9 %, Fillrate = 94.8 %
# Discount = 10%, Profit = 159.396, Waste = 9.4 %, Fillrate = 95.0 %
# Discount = 15%, Profit = 159.882, Waste = 9.0 %, Fillrate = 95.0 %
# Discount = 20%, Profit = 160.147, Waste = 8.5 %, Fillrate = 95.2 %
# Discount = 25%, Profit = 159.225, Waste = 8.0 %, Fillrate = 95.3 %
# Discount = 30%, Profit = 157.683, Waste = 7.5 %, Fillrate = 95.4 %
# Discount = 35%, Profit = 155.760, Waste = 7.0 %, Fillrate = 95.6 %
# Discount = 40%, Profit = 152.848, Waste = 6.5 %, Fillrate = 95.6 %
# Discount = 45%, Profit = 149.424, Waste = 6.0 %, Fillrate = 95.7 %
# Discount = 50%, Profit = 145.467, Waste = 5.6 %, Fillrate = 95.8 %

# %% [markdown]
# ## Plot out the baseline figure

# %%
plt.plot(5 * np.arange(11), Profit, marker='o')  # Line plot with points
plt.title("Fixed last-day discounting")
plt.xlabel("discount %")
plt.ylabel("profit")
plt.grid(True)
plt.show()

# plt.plot(D)
# plt.show()
# plt.plot(LS)
# plt.show()

df = pd.DataFrame(
    {'I': list(I[0:T]) ,
     'BSPlvl': BSPlvl,
     'Order': Order,
     'D': D,
     'Delta': list(DeltaF + DeltaF),
     'LS': LS,
     'Wst': WST,
     'Prf': PRF
     })

print(df.head(10))
print(df.tail(10))
# Out:
#                  I  BSPlvl  Order  D            Delta  LS  Wst     Prf
# 0  [0, 0, 0, 0, 0]       9      9  2  [0, 0, 0, 0, 0]   2    0 -1575.0
# 1  [9, 0, 0, 0, 0]       9      0  1  [0, 0, 0, 0, 0]   0    0   250.0
# 2  [0, 8, 0, 0, 0]       9      1  1  [0, 0, 0, 0, 0]   0    0    75.0
# 3  [1, 0, 7, 0, 0]       9      1  3  [0, 0, 0, 0, 0]   0    0   575.0
# 4  [1, 0, 0, 5, 0]       9      3  3  [0, 0, 0, 0, 0]   0    0   225.0
# 5  [3, 0, 0, 0, 3]       9      3  3  [0, 0, 0, 0, 4]   0    1   -25.0
# 6  [3, 2, 0, 0, 0]       9      4  3  [0, 0, 0, 0, 0]   0    0    50.0
# 7  [4, 0, 2, 0, 0]       9      3  3  [0, 0, 0, 0, 0]   0    0   225.0
# 8  [3, 1, 0, 2, 0]       9      3  0  [0, 0, 0, 0, 0]   0    0  -525.0
# 9  [3, 3, 1, 0, 2]       9      0  2  [0, 0, 0, 0, 2]   0    1   375.0
#                      I  BSPlvl  Order  D            Delta  LS  Wst    Prf
# 36500  [4, 0, 0, 0, 2]       9      3  2  [0, 0, 0, 0, 2]   0    1 -150.0
# 36501  [3, 3, 0, 0, 0]       9      3  3  [0, 0, 0, 0, 0]   0    0  225.0
# 36502  [3, 0, 3, 0, 0]       9      3  2  [0, 0, 0, 0, 0]   0    0  -25.0
# 36503  [3, 1, 0, 3, 0]       9      2  3  [0, 0, 0, 0, 0]   0    0  400.0
# 36504  [2, 0, 1, 0, 3]       9      3  3  [0, 0, 0, 0, 4]   0    1  -25.0
# 36505  [3, 1, 0, 1, 0]       9      4  3  [0, 0, 0, 0, 0]   0    0   50.0
# 36506  [4, 0, 1, 0, 1]       9      3  1  [0, 0, 0, 0, 0]   0    1 -275.0
# 36507  [3, 3, 0, 1, 0]       9      2  4  [0, 0, 0, 0, 0]   0    0  650.0
# 36508  [2, 0, 2, 0, 1]       9      4  4  [0, 0, 0, 0, 2]   0    0  175.0
# 36509  [4, 0, 0, 1, 0]       9      4  2  [0, 0, 0, 0, 0]   0    0 -200.0

# %% [markdown]
# # Run the policy on the model

# %%
I, IL, BSPlvl, Order, D, DF, DL, DeltaF, DeltaL, SALES, PRF, LS, WST, Profit = initialize()

rd.seed(1)
np.random.seed(1)
I[:] = np.zeros([T + 1, M], dtype=int)
IL[:] = np.zeros([T, M], dtype=int)
BSPlvl[:] = np.zeros(T, dtype=int)
Order[:] = np.zeros(T, dtype=int)
D[:] = np.zeros(T, dtype=int)
DF[:] = np.zeros(T, dtype=int)
DL[:] = np.zeros(T, dtype=int)
DeltaF[:] = np.zeros([T, M], dtype=int)
DeltaL[:] = np.zeros([T, M], dtype=int)
SALES[:] = np.zeros(T, dtype=int)
PRF[:] = np.zeros(T)
LS[:] = np.zeros(T, dtype=int)
WST[:] = np.zeros(T, dtype=int)

# SIMULATE INVENTORY DYANMICS OVER ALL PERIODS
for t in range(T):

    # predict demand and set BSP level
    BSPlvl[t] = round(2 * mu + z * sqrt(2) * mu)

    # set discount
    pi_a_idx = np.where((SS == I[t]).all(axis = 1))[0][0].item()
    a = 0.05 * pi[pi_a_idx]

    # set order quantity:
    Order[t] = max(0, BSPlvl[t] - I[t].sum())

    # set demand:
    D[t] = min(Dmx, np.random.poisson(mu))

    # split demand
    DF_frac = min(I[t, M - 1], a * D[t])
    DF_int = int(DF_frac)
    DF[t] = DF_int
    if DF_frac != DF_int:  # stochastic rounding
        Frac = DF_frac - DF_int
        u = rd.random()
        if u < Frac:
            DF[t] = DF_int + 1
    DL[t] = D[t] - DF[t]

    # pick FEFO demand:
    DeltaF[t, M - 1] = DF[t]  # only oldest are discounted (<= max I[t,M-1])

    # available for LEFO customers/adjust stock levels:
    IL[t] = I[t] - DeltaF[t]

    # pick LEFO demand:
    DeltaL[t, 0] = min(DL[t], IL[t, 0])  # youngest first
    for i in range(1, M):
        DeltaL[t, i] = min(DL[t] - DeltaL[t, 0:i].sum(), IL[t, i])

    # adjust stock levels:
    I[t + 1, :] = IL[t] - DeltaL[t]
    WST[t] = I[t + 1, M - 1]
    I[t + 1, :] = np.roll(I[t + 1], 1)
    I[t + 1, 0] = Order[t]  # as lead time is one period

    # more stats:
    LS[t] = max(0, D[t] - I[t].sum())
    SALES[t] = DeltaF[t].sum() + DeltaL[t].sum()
    PRF[t] = r * DeltaL[t].sum() + r * (1 - a) * DeltaF[t].sum() - c * Order[t]

WasteRel = WST[Tw:T].mean() / Order[Tw:T].mean()
Fillrate = 1 - LS[Tw:T].mean() / D[Tw:T].mean()
Profit = PRF[Tw:T].mean()
print(f"Profit = {Profit:.3f}, Waste = {WasteRel * 100:.1f} %, Fillrate = {Fillrate * 100:.1f} %")
# Out:
# Profit = 161.544, Waste = 8.3 %, Fillrate = 95.3 %

# %% [markdown]
# # Value iteration

# %%
# stop criteria:
K = 20
Theta = 1
gamma = 0.9
#initialization
V = np.zeros(nS)
stop = False
k = 0
# value iteration
pi = np.zeros(nS)
while not stop:
    k += 1
    print(k)
    Delta = 0

    for ids, s in enumerate(SS):
        vs = V[ids]
        Vbest = -99999

        for ida, a in enumerate(AA):
            Vtry = RR[ida,ids] + gamma * PP[ida, ida, :] @ V
            if Vtry > Vbest:
                Vbest = Vtry
                pi[ids] = a
        V[ids] = Vbest
        if Delta < abs(V[ids] - vs):
            Delta = abs(V[ids] - vs)
    print(Delta)
    if (k == K) or (Delta < Theta):
        stop = True
# Out:
# 1
# 3560.9600321550024
# 2
# 3204.8640289395025
# 3
# 2073.0356561998933
# 4
# 1458.965467244895
# 5
# 1058.2905435999965
# 6
# 821.8564036181742
# 7
# 662.389343433324
# 8
# 533.8641158752534
# 9
# 430.2769919908187
# 10
# 346.7891628811558

# %%
pi = np.random.choice(AA, nS)  # fixed policy
V = np.zeros(len(SS))
gamma = 0.9
# Iterative Policy evaluation
niterVI = 0

# stop criteria:
K = 50
Theta = 1
gamma = 0.8
#initialization
V = np.zeros(nS)
stop = False
k = 0
while not stop:
    k += 1
    Delta = 0

    for ids, s in enumerate(SS):
        vs = V[ids]
        Vbest = -99999

        for ida, a in enumerate(AA):
            Vtry = RR[ida,ids] + gamma * PP[ida, ids, :] @ V
            if Vtry > Vbest:
                Vbest = Vtry
                pi[ids] = a
        V[ids] = Vbest
        if Delta < abs(V[ids] - vs):
            Delta = abs(V[ids] - vs)
    if (k == K) or (Delta < Theta):
        stop = True
    niterVI += 1

print(niterVI, pi)
# Out:
# 17 [0 0 0 ... 0 0 0]

# %%
I, IL, BSPlvl, Order, D, DF, DL, DeltaF, DeltaL, SALES, PRF, LS, WST, Profit = initialize()

rd.seed(1)
np.random.seed(1)
I[:] = np.zeros([T + 1, M], dtype=int)
IL[:] = np.zeros([T, M], dtype=int)
BSPlvl[:] = np.zeros(T, dtype=int)
Order[:] = np.zeros(T, dtype=int)
D[:] = np.zeros(T, dtype=int)
DF[:] = np.zeros(T, dtype=int)
DL[:] = np.zeros(T, dtype=int)
DeltaF[:] = np.zeros([T, M], dtype=int)
DeltaL[:] = np.zeros([T, M], dtype=int)
SALES[:] = np.zeros(T, dtype=int)
PRF[:] = np.zeros(T)
LS[:] = np.zeros(T, dtype=int)
WST[:] = np.zeros(T, dtype=int)

# SIMULATE INVENTORY DYANMICS OVER ALL PERIODS
for t in range(T):

    # predict demand and set BSP level
    BSPlvl[t] = round(2 * mu + z * sqrt(2) * mu)

    # set discount
    pi_a_idx = np.where((SS == I[t]).all(axis = 1))[0][0].item()
    a = 0.05 * pi[pi_a_idx]

    # set order quantity:
    Order[t] = max(0, BSPlvl[t] - I[t].sum())

    # set demand:
    D[t] = min(Dmx, np.random.poisson(mu))

    # split demand
    DF_frac = min(I[t, M - 1], a * D[t])
    DF_int = int(DF_frac)
    DF[t] = DF_int
    if DF_frac != DF_int:  # stochastic rounding
        Frac = DF_frac - DF_int
        u = rd.random()
        if u < Frac:
            DF[t] = DF_int + 1
    DL[t] = D[t] - DF[t]

    # pick FEFO demand:
    DeltaF[t, M - 1] = DF[t]  # only oldest are discounted (<= max I[t,M-1])

    # available for LEFO customers/adjust stock levels:
    IL[t] = I[t] - DeltaF[t]

    # pick LEFO demand:
    DeltaL[t, 0] = min(DL[t], IL[t, 0])  # youngest first
    for i in range(1, M):
        DeltaL[t, i] = min(DL[t] - DeltaL[t, 0:i].sum(), IL[t, i])

    # adjust stock levels:
    I[t + 1, :] = IL[t] - DeltaL[t]
    WST[t] = I[t + 1, M - 1]
    I[t + 1, :] = np.roll(I[t + 1], 1)
    I[t + 1, 0] = Order[t]  # as lead time is one period

    # more stats:
    LS[t] = max(0, D[t] - I[t].sum())
    SALES[t] = DeltaF[t].sum() + DeltaL[t].sum()
    PRF[t] = r * DeltaL[t].sum() + r * (1 - a) * DeltaF[t].sum() - c * Order[t]

WasteRel = WST[Tw:T].mean() / Order[Tw:T].mean()
Fillrate = 1 - LS[Tw:T].mean() / D[Tw:T].mean()
Profit = PRF[Tw:T].mean()
print(f"Profit = {Profit:.3f}, Waste = {WasteRel * 100:.1f} %, Fillrate = {Fillrate * 100:.1f} %")
# Out:
# Profit = 161.330, Waste = 8.6 %, Fillrate = 95.2 %
